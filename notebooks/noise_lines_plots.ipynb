# %% [markdown]
# ## Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from inverse_problem.milne_edington.me import HinodeME, me_model, _compute_spectrum, _prepare_base_model_parameters, _prepare_zero_model_parameters

# %%
param_vec = np.array([500, 20, 20, 20, 1, 10, 10000, 10000, 0, 1, 0])

# %%
hinode = HinodeME(param_vec)
noised = hinode.compute_spectrum()

# %%
noised[0].shape
# Out:
# (56, 4)

# %%
def plot_spectrum(profile):

    plt.title('sample spectrum')


    for i in range(4):
        plt.subplot(2,2,i+1)
        plt.plot((profile.T)[i])

a = plot_spectrum(noised)

# %%
no_noise = hinode.compute_spectrum(with_noise=False)
plot_spectrum(no_noise)
